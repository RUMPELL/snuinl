# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import nibabel as nib
import pandas as pd
import os
import shutil
from torch.utils.data import DataLoader

# %%
if torch.cuda.is_available():
    DEVICE = torch.device('cuda:0')
else:
    DEVICE = torch.device('cpu')
    
print("Using PyTorch version:", torch.__version__, 'Device: ', DEVICE)
# Out:
# Using PyTorch version: 1.12.0+cu116 Device:  cuda:0

# %%
path2xls = './IXI.xls'
labels_df = pd.read_excel(path2xls)
labels_df.head()
# Out:
#    IXI_ID  SEX_ID (1=m, 2=f)  HEIGHT  WEIGHT  ETHNIC_ID  MARITAL_ID  \
# 0       1                  1     170      80          2           3
# 1       2                  2     164      58          1           4
# 2      12                  1     175      70          1           2
# 3      13                  1     182      70          1           2
# 4      14                  2     163      65          1           4
#
#    OCCUPATION_ID  QUALIFICATION_ID         DOB  DATE_AVAILABLE STUDY_DATE  \
# 0              5                 2  1968-02-22               0        NaT
# 1              1                 5  1970-01-30               1 2005-11-18
# 2              1                 5  1966-08-20               1 2005-06-01
# 3              1                 5  1958-09-15               1 2005-06-01
# 4              1                 5  1971-03-15               1 2005-06-09
#
#          AGE
# 0        NaN
# 1  35.800137
# 2  38.781656
# 3  46.710472
# 4  34.236824

# %%
labels_df['IXI_ID']
# Out:
# 0        1
# 1        2
# 2       12
# 3       13
# 4       14
#       ...
# 614    652
# 615    653
# 616    655
# 617    660
# 618    662
# Name: IXI_ID, Length: 619, dtype: int64

# %%
age_df = labels_df[['IXI_ID', 'AGE']]
age_df
# Out:
#      IXI_ID        AGE
# 0         1        NaN
# 1         2  35.800137
# 2        12  38.781656
# 3        13  46.710472
# 4        14  34.236824
# ..      ...        ...
# 614     652  42.989733
# 615     653  46.220397
# 616     655        NaN
# 617     660        NaN
# 618     662  41.741273
#
# [619 rows x 2 columns]

# %%
path_dir = './IXI'
file_list = os.listdir(path_dir)
file_list
# Out:
# ['swc1nIXI016-Guys-0697-IXI3DMPRAG_-s231_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI138-Guys-0746-IXI3DMPRAG_-s240_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI077-Guys-0752-IXI3DMPRAG_-s242_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI468-Guys-0985-MPRAGESEN_-s417_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI629-Guys-1095-MPRAGESEN_-sIXI62_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI496-Guys-1045-MPRAGESEN_-s421_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI639-Guys-1088-MPRAGESEN_-s445_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI336-Guys-0904-MPRAGESEN_-s306_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI420-Guys-1028-MPRAGESEN_-s424_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI307-IOP-0872-SAGFSPGR_-sIXI30_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI219-Guys-0894-MPRAGESEN_-s304_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI303-IOP-0968-SAGFSPGR_-sIXI30_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI178-Guys-0778-IXI3DMPRAG_-s248_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI423-IOP-0974-SAGFSPGR_-sIXI00_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI309-IOP-0897-SAGFSPGR_-sIXI30_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI279-Guys-1044-MPRAGESEN_-s295_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI344-Guys-0905-MPRAGESEN_-s306_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI153-Guys-0782-IXI3DMPRAG_-s249_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI123-Guys-0774-IXI3DMPRAG_-s247_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI536-Guys-1059-MPRAGESEN_-s427_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI331-IOP-0892-SAGFSPGR_-sIXI33_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI143-Guys-0785-IXI3DMPRAG_-s249_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI474-IOP-1138-SAGFSPGR_-sIXI47_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI450-Guys-1093-MPRAGESEN_-s447_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI528-Guys-1073-MPRAGESEN_-sIXI52_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI268-Guys-0858-MPRAGESEN_-s296_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI170-Guys-0843-MPRAGESEN_-s260_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI233-IOP-0875-SAGFSPGR_-sIXI23_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI087-Guys-0768-IXI3DMPRAG_-s246_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI587-Guys-1128-MPRAGESEN_-sIXI0587_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI640-Guys-1106-MPRAGESEN_-s452_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI368-Guys-0916-MPRAGESEN_-s403_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI222-Guys-0819-MPRAGESEN_-s222_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI431-Guys-0986-MPRAGESEN_-s417_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI193-Guys-0810-MPRAGESEN_-s254_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI044-Guys-0712-IXI3DMPRAG_-s235_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI076-Guys-0753-IXI3DMPRAG_-s242_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI158-Guys-0783-IXI3DMPRAG_-s249_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI119-Guys-0765-IXI3DMPRAG_-s245_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI027-Guys-0710-IXI3DMPRAG_-s234_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI495-Guys-1009-MPRAGESEN_-s421_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI114-Guys-0737-IXI3DMPRAG_-s239_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI662-Guys-1120-MPRAGESEN_-s455_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI109-Guys-0732-IXI3DMPRAG_-s238_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI200-Guys-0812-MPRAGESEN_-s254_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI188-Guys-0798-MPRAGESEN_-s252_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI300-Guys-0880-MPRAGESEN_-s299_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI393-Guys-0941-MPRAGESEN_-s407_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI442-IOP-1041-SAGFSPGR_-sIXI44_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI576-Guys-1077-MPRAGESEN_-sIXI57_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI351-Guys-0914-MPRAGESEN_-s401_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI461-Guys-0998-MPRAGESEN_-s419_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI573-IOP-1155-SAGFSPGR_-sIXI57_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI597-IOP-1161-SAGFSPGR_-sIXI59_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI164-Guys-0844-MPRAGESEN_-s260_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI574-IOP-1156-SAGFSPGR_-sIXI57_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI207-Guys-0809-MPRAGESEN_-s253_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI026-Guys-0696-IXI3DMPRAG_-s230_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI192-Guys-0878-MPRAGESEN_-s299_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI028-Guys-1038-MPRAGESEN_-s425_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI413-Guys-0955-MPRAGESEN_-s414_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI594-Guys-1089-MPRAGESEN_-s445_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI063-Guys-0742-IXI3DMPRAG_-s240_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI621-Guys-1100-MPRAGESEN_-sIXI62_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI294-IOP-0868-SAGFSPGR_-sIXI29_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI399-Guys-0966-MPRAGESEN_-s413_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI498-Guys-1050-MPRAGESEN_-s426_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI641-Guys-1105-MPRAGESEN_-s451_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI084-Guys-0741-IXI3DMPRAG_-s240_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI232-IOP-0898-SAGFSPGR_-sIXI23_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI196-Guys-0805-MPRAGESEN_-s253_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI417-Guys-0939-MPRAGESEN_-s408_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI332-IOP-1134-SAGFSPGR_-sIXI33_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI024-Guys-0705-IXI3DMPRAG_-s232_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI493-Guys-1007-MPRAGESEN_-s420_-0601-00006-000001-01_RAS_denoised.nii',
#  'swc1nIXI411-Guys-0959-MPRAGESEN_-s414_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI050-Guys-0711-IXI3DMPRAG_-s235_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI552-Guys-1063-MPRAGESEN_-s428_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI037-Guys-0704-IXI3DMPRAG_-s232_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI209-Guys-0804-MPRAGESEN_-s253_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI055-Guys-0730-IXI3DMPRAG_-sIXI0055_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI390-Guys-0931-MPRAGESEN_-sIXI0390_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI315-IOP-0888-SAGFSPGR_-sIXI31_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI401-Guys-0978-MPRAGESEN_-s416_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI548-IOP-1150-SAGFSPGR_-sIXI54_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI017-Guys-0698-IXI3DMPRAG_-s231_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI113-Guys-0776-IXI3DMPRAG_-s247_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI154-Guys-0821-MPRAGESEN_-s255_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI595-IOP-1159-SAGFSPGR_-sIXI59_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI045-Guys-0713-IXI3DMPRAG_-s235_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI652-Guys-1116-MPRAGESEN_-s454_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI342-Guys-0909-MPRAGESEN_-s034_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI653-Guys-1122-MPRAGESEN_-sIXI653_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI036-Guys-0736-IXI3DMPRAG_-s239_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI265-Guys-0845-MPRAGESEN_-s262_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI500-Guys-1017-MPRAGESEN_-s422_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI064-Guys-0743-IXI3DMPRAG_-s240_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI182-Guys-0792-MPRAGESEN_-s251_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI115-Guys-0738-IXI3DMPRAG_-s239_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI415-Guys-0942-MPRAGESEN_-s407_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI549-Guys-1046-MPRAGESEN_-s426_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI388-IOP-0973-SAGFSPGR_-sIXI38_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI463-IOP-1043-SAGFSPGR_-sIXI46_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI023-Guys-0699-IXI3DMPRAG_-s231_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI112-Guys-0735-IXI3DMPRAG_-s239_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI488-Guys-1015-MPRAGESEN_-s421_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI308-Guys-0884-MPRAGESEN_-s302_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI359-Guys-0918-MPRAGESEN_-s404_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI433-IOP-0989-SAGFSPGR_-sIXI43_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI020-Guys-0700-IXI3DMPRAG_-s231_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI408-Guys-0962-MPRAGESEN_-s414_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI365-Guys-0923-MPRAGESEN_-s402_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI418-Guys-0956-MPRAGESEN_-s414_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI381-Guys-1024-MPRAGESEN_-s424_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI364-Guys-0920-MPRAGESEN_-s403_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI469-IOP-1136-SAGFSPGR_-sIXI46_-0005-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI430-IOP-0990-SAGFSPGR_-sIXI43_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI370-Guys-0921-MPRAGESEN_-s402_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI288-Guys-0879-MPRAGESEN_-s299_-0501-00005-000001-01_RAS_denoised.nii',
#  'swc1nIXI241-Guys-0833-MPRAGESEN_-s257_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI454-Guys-1083-MPRAGESEN_-sIXI45_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI035-IOP-0873-SAGFSPGR_-sIXI35_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI330-Guys-0881-MPRAGESEN_-s299_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI371-IOP-0970-SAGFSPGR_-sIXI37_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI043-Guys-0714-IXI3DMPRAG_-s235_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI480-Guys-1033-MPRAGESEN_-s425_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI416-Guys-1051-MPRAGESEN_-s426_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI644-Guys-1121-MPRAGESEN_-s455_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI157-Guys-0816-MPRAGESEN_-s254_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI625-Guys-1098-MPRAGESEN_-sIXI624_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI118-Guys-0764-IXI3DMPRAG_-s245_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI073-Guys-0755-IXI3DMPRAG_-s242_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI464-IOP-1029-SAGFSPGR_-sIXI46_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI426-IOP-1011-SAGFSPGR_-sIXI42_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI183-Guys-0791-MPRAGESEN_-s251_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI648-Guys-1107-MPRAGESEN_-sIXI0648_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI456-Guys-1019-MPRAGESEN_-s423_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI409-Guys-0960-MPRAGESEN_-s415_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI230-IOP-0869-SAGFSPGR_-sIXI23_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI348-Guys-0910-MPRAGESEN_-s034_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI592-Guys-1085-MPRAGESEN_-sIXI59_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI166-Guys-0846-MPRAGESEN_-s262_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI324-Guys-0922-MPRAGESEN_-s402_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI061-Guys-0715-IXI3DMPRAG_-s235_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI558-Guys-1079-MPRAGESEN_-s433_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI172-Guys-0982-MPRAGESEN_-s417_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI041-Guys-0706-IXI3DMPRAG_-s234_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI491-Guys-1032-MPRAGESEN_-s425_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI523-Guys-1056-MPRAGESEN_-s427_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI551-Guys-1065-MPRAGESEN_-s428_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI312-Guys-0887-MPRAGESEN_-s302_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI305-IOP-0871-SAGFSPGR_-sIXI30_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI503-Guys-1021-MPRAGESEN_-s423_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI197-Guys-0811-MPRAGESEN_-s253_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI434-IOP-1010-SAGFSPGR_-sIXI43_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI224-Guys-0823-MPRAGESEN_-s255_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI517-IOP-1144-SAGFSPGR_-sIXI51_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI074-Guys-0771-IXI3DMPRAG_-s246_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI375-Guys-0925-MPRAGESEN_-sIXI037_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI400-Guys-0977-MPRAGESEN_-s416_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI563-IOP-1153-SAGFSPGR_-sIXI56_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI120-Guys-0766-IXI3DMPRAG_-s245_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI406-Guys-0963-MPRAGESEN_-s414_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI326-Guys-0907-MPRAGESEN_-s307_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI285-Guys-0857-MPRAGESEN_-s295_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI186-Guys-0796-MPRAGESEN_-s252_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI100-Guys-0747-IXI3DMPRAG_-s241_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI286-Guys-0859-MPRAGESEN_-s296_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI025-Guys-0852-MPRAGESEN_-s294_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI199-Guys-0802-MPRAGESEN_-s253_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI266-Guys-0853-MPRAGESEN_-s294_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI617-Guys-1090-MPRAGESEN_-s445_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI022-Guys-0701-IXI3DMPRAG_-s231_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI223-Guys-0830-MPRAGESEN_-s256_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI231-IOP-0866-SAGFSPGR_-sIXI23_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI210-Guys-0856-MPRAGESEN_-s295_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI372-IOP-0971-SAGFSPGR_-sIXI37_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI145-Guys-0781-IXI3DMPRAG_-s248_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI029-Guys-0829-MPRAGESEN_-s256_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI510-IOP-1143-SAGFSPGR_-sIXI51_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI251-Guys-1055-MPRAGESEN_-s426_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI460-Guys-0999-MPRAGESEN_-s419_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI065-Guys-0744-IXI3DMPRAG_-s240_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI502-Guys-1020-MPRAGESEN_-s422_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI021-Guys-0703-IXI3DMPRAG_-s232_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI427-IOP-1012-SAGFSPGR_-sIXI42_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI181-Guys-0790-MPRAGESEN_-s251_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI140-Guys-0787-IXI3DMPRAG_-s249_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI382-IOP-1135-SAGFSPGR_-sIXI38_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI237-Guys-1049-MPRAGESEN_-s426_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI494-Guys-1008-MPRAGESEN_-s421_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI227-Guys-0813-MPRAGESEN_-s254_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI487-Guys-1037-MPRAGESEN_-s425_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI142-Guys-0786-IXI3DMPRAG_-s249_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI244-Guys-0841-MPRAGESEN_-s260_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI099-Guys-0748-IXI3DMPRAG_-s241_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI306-IOP-0867-SAGFSPGR_-sIXI30_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI299-Guys-0893-MPRAGESEN_-s304_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI550-Guys-1069-MPRAGESEN_-s429_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI512-Guys-1054-MPRAGESEN_-s426_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI588-IOP-1158-SAGFSPGR_-sIXI58_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI584-Guys-1129-MPRAGESEN_-sIXI58_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI311-Guys-0885-MPRAGESEN_-s302_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI054-Guys-0707-IXI3DMPRAG_-s234_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI317-Guys-0896-MPRAGESEN_-s304_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI319-Guys-0901-MPRAGESEN_-s306_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI320-Guys-0902-MPRAGESEN_-s306_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI111-Guys-0734-IXI3DMPRAG_-s239_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI042-Guys-0725-IXI3DMPRAG_-s237_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI397-Guys-0953-MPRAGESEN_-s412_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI297-Guys-0886-MPRAGESEN_-s302_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI505-Guys-1026-MPRAGESEN_-s424_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI229-Guys-0980-MPRAGESEN_-s416_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI129-Guys-0775-IXI3DMPRAG_-s247_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI108-Guys-0865-MPRAGESEN_-s298_-0601-00006-000001-01_RAS_denoised.nii',
#  'swc1nIXI318-Guys-0895-MPRAGESEN_-s304_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI504-Guys-1025-MPRAGESEN_-s424_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI622-Guys-1102-MPRAGESEN_-sIXI62_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI293-IOP-0876-SAGFSPGR_-sIXI29_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI398-Guys-0952-MPRAGESEN_-s412_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI389-Guys-0930-MPRAGESEN_-sIXI0389_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI391-Guys-0934-MPRAGESEN_-sIXI0391_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI507-Guys-1036-MPRAGESEN_-s425_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI070-Guys-0767-IXI3DMPRAG_-s246_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI361-Guys-0913-MPRAGESEN_-s401_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI432-Guys-0987-MPRAGESEN_-s418_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI078-Guys-0751-IXI3DMPRAG_-s242_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI031-Guys-0797-MPRAGESEN_-s252_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI543-IOP-1148-SAGFSPGR_-sIXI54_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI122-Guys-0773-IXI3DMPRAG_-s247_-0501-00005-000001-01_RAS_denoised.nii',
#  'swc1nIXI208-Guys-0808-MPRAGESEN_-s253_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI422-Guys-1071-MPRAGESEN_-s429_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI046-Guys-0824-MPRAGESEN_-s255_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI542-IOP-1147-SAGFSPGR_-sIXI54_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI089-Guys-0757-IXI3DMPRAG_-s244_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI532-IOP-1145-SAGFSPGR_-sIXI53_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI040-Guys-0724-IXI3DMPRAG_-sIXI0040_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI069-Guys-0769-IXI3DMPRAG_-s246_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI410-Guys-0958-MPRAGESEN_-s414_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI287-Guys-0863-MPRAGESEN_-s298_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI184-Guys-0794-MPRAGESEN_-s252_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI298-Guys-0861-MPRAGESEN_-s298_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI189-Guys-0799-MPRAGESEN_-s252_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI539-Guys-1067-MPRAGESEN_-s429_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI402-Guys-0961-MPRAGESEN_-s413_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI478-IOP-1142-SAGFSPGR_-sIXI47_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI555-Guys-1074-MPRAGESEN_-sIXI55_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI350-Guys-0908-MPRAGESEN_-sO35_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI627-Guys-1103-MPRAGESEN_-s450_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI110-Guys-0733-IXI3DMPRAG_-s239_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI360-Guys-0912-MPRAGESEN_-s401_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI134-Guys-0780-IXI3DMPRAG_-s248_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI121-Guys-0772-IXI3DMPRAG_-s247_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI236-Guys-0817-MPRAGESEN_-s254_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI569-Guys-1101-MPRAGESEN_-s449_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI541-IOP-1146-SAGFSPGR_-sIXI54_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI068-Guys-0756-IXI3DMPRAG_-s244_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI030-Guys-0708-IXI3DMPRAG_-s234_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI582-Guys-1127-MPRAGESEN_-sIXI0582_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI412-Guys-0949-MPRAGESEN_-s412_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI404-Guys-0950-MPRAGESEN_-s412_-0801-00008-000001-01_RAS_denoised.nii',
#  'swc1nIXI066-Guys-0731-IXI3DMPRAG_-s238_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI141-Guys-0789-MPRAGESEN_-s251_-0501-00005-000001-01_RAS_denoised.nii',
#  'swc1nIXI479-Guys-1034-MPRAGESEN_-s425_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI086-Guys-0728-IXI3DMPRAG_-s237_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI425-IOP-0988-SAGFSPGR_-sIXI42_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI367-Guys-0917-MPRAGESEN_-s404_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI234-IOP-0870-SAGFSPGR_-sIXI23_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI019-Guys-0702-IXI3DMPRAG_-s232_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI473-IOP-1137-SAGFSPGR_-sIXI47_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI619-Guys-1099-MPRAGESEN_-sIXI61_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI379-Guys-0943-MPRAGESEN_-s407_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI414-Guys-0957-MPRAGESEN_-s414_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI156-Guys-0837-MPRAGESEN_-s259_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI151-Guys-0793-MPRAGESEN_-s251_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI535-Guys-1061-MPRAGESEN_-s427_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI058-Guys-0726-IXI3DMPRAG_-s237_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI225-Guys-0832-MPRAGESEN_-s257_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI630-Guys-1108-MPRAGESEN_-sIXI0630_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI179-Guys-0777-IXI3DMPRAG_-s247_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI103-Guys-0750-IXI3DMPRAG_-s241_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI579-Guys-1126-MPRAGESEN_-s433_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI062-Guys-0740-IXI3DMPRAG_-sIXI0062_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI486-Guys-1005-MPRAGESEN_-s420_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI467-Guys-0983-MPRAGESEN_-s417_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI394-Guys-0940-MPRAGESEN_-s407_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI501-Guys-1016-MPRAGESEN_-s422_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI419-Guys-1027-MPRAGESEN_-s424_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI407-Guys-0964-MPRAGESEN_-s414_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI376-Guys-0938-MPRAGESEN_-s408_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI291-IOP-0882-SAGFSPGR_-sIXI29_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI177-Guys-0831-MPRAGESEN_-s257_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI475-IOP-1139-SAGFSPGR_-sIXI47_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI607-Guys-1097-MPRAGESEN_-s445_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI249-Guys-1072-MPRAGESEN_-sIXI24_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI325-Guys-0911-MPRAGESEN_-s032_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI194-Guys-0818-MPRAGESEN_-s254_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI269-Guys-0839-MPRAGESEN_-s259_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI553-IOP-1151-SAGFSPGR_-sIXI55_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI090-Guys-0800-MPRAGESEN_-s252_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI489-Guys-1014-MPRAGESEN_-s421_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI571-IOP-1154-SAGFSPGR_-sIXI57_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI314-IOP-0889-SAGFSPGR_-sIXI31_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI403-Guys-0965-MPRAGESEN_-s413_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI424-IOP-0991-SAGFSPGR_-sIXI42_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI091-Guys-0762-IXI3DMPRAG_-s245_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI578-Guys-1078-MPRAGESEN_-s433_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI618-Guys-1091-MPRAGESEN_-s445_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI616-Guys-1092-MPRAGESEN_-s445_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI380-Guys-0944-MPRAGESEN_-s407_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI596-IOP-1160-SAGFSPGR_-sIXI59_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI476-IOP-1140-SAGFSPGR_-sIXI47_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI053-Guys-0727-IXI3DMPRAG_-s237_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI626-Guys-1094-MPRAGESEN_-s447_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI562-Guys-1131-MPRAGESEN_-sIXI0562_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI310-IOP-0890-SAGFSPGR_-sIXI31_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI060-Guys-0709-IXI3DMPRAG_-s234_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI198-Guys-0803-MPRAGESEN_-s253_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI405-Guys-0948-MPRAGESEN_-s412_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI321-Guys-0903-MPRAGESEN_-s306_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI449-Guys-1082-MPRAGESEN_-s442_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI533-Guys-1066-MPRAGESEN_-s428_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI169-Guys-0842-MPRAGESEN_-s260_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI135-Guys-0779-IXI3DMPRAG_-s248_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI477-IOP-1141-SAGFSPGR_-sIXI47_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI534-Guys-1062-MPRAGESEN_-s427_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI191-Guys-0801-MPRAGESEN_-s252_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI238-IOP-0883-SAGFSPGR_-sIXI23_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI358-Guys-0919-MPRAGESEN_-s404_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI071-Guys-0770-IXI3DMPRAG_-s246_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI304-Guys-0862-MPRAGESEN_-s298_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI098-Guys-0745-IXI3DMPRAG_-s240_-0701-00007-000001-01_RAS_denoised.nii',
#  'swc1nIXI250-Guys-0836-MPRAGESEN_-s259_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI651-Guys-1118-MPRAGESEN_-s454_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI554-Guys-1068-MPRAGESEN_-s429_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI270-Guys-0847-MPRAGESEN_-s263_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI369-Guys-0924-MPRAGESEN_-s402_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI322-IOP-0891-SAGFSPGR_-sIXI32_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI289-Guys-0864-MPRAGESEN_-s298_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI560-Guys-1070-MPRAGESEN_-s429_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI547-IOP-1149-SAGFSPGR_-sIXI54_-0004-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI101-Guys-0749-IXI3DMPRAG_-s241_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI455-Guys-0981-MPRAGESEN_-s416_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI116-Guys-0739-IXI3DMPRAG_-s239_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI377-Guys-0937-MPRAGESEN_-s408_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI506-Guys-1035-MPRAGESEN_-s425_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI392-Guys-1064-MPRAGESEN_-s428_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI447-Guys-0979-MPRAGESEN_-s416_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI642-Guys-1104-MPRAGESEN_-s451_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI395-IOP-0969-SAGFSPGR_-sIXI39_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI246-Guys-0840-MPRAGESEN_-s260_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI292-IOP-0877-SAGFSPGR_-sIXI29_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI499-Guys-1004-MPRAGESEN_-s420_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI075-Guys-0754-IXI3DMPRAG_-s242_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI139-Guys-0815-MPRAGESEN_-s254_-0401-00004-000001-01_RAS_denoised.nii',
#  'swc1nIXI429-Guys-0997-MPRAGESEN_-s419_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI591-Guys-1084-MPRAGESEN_-sIXI59_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI085-Guys-0759-IXI3DMPRAG_-s244_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI144-Guys-0788-IXI3DMPRAG_-s250_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI492-Guys-1022-MPRAGESEN_-s423_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI290-IOP-0874-SAGFSPGR_-sIXI29_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI585-Guys-1130-MPRAGESEN_-sIXI58_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI185-Guys-0795-MPRAGESEN_-s252_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI561-IOP-1152-SAGFSPGR_-sIXI56_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI462-IOP-1042-SAGFSPGR_-sIXI46_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI247-Guys-0838-MPRAGESEN_-s259_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI459-Guys-0992-MPRAGESEN_-s418_-0601-00006-000001-01_RAS_denoised.nii',
#  'swc1nIXI002-Guys-0828-MPRAGESEN_-s256_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI378-IOP-0972-SAGFSPGR_-sIXI37_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI470-IOP-1030-SAGFSPGR_-sIXI47_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI490-Guys-1018-MPRAGESEN_-s422_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI497-Guys-1002-MPRAGESEN_-s420_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI264-Guys-0854-MPRAGESEN_-s294_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI240-Guys-0834-MPRAGESEN_-s258_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI106-Guys-0760-IXI3DMPRAG_-s245_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI107-Guys-0761-IXI3DMPRAG_-s245_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI373-IOP-0967-SAGFSPGR_-sIXI37_-0003-00001-000001-01_RAS_denoised.nii',
#  'swc1nIXI428-Guys-0996-MPRAGESEN_-s419_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI531-Guys-1057-MPRAGESEN_-s427_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI458-Guys-0993-MPRAGESEN_-s418_-0301-00003-000001-01_RAS_denoised.nii',
#  'swc1nIXI038-Guys-0729-IXI3DMPRAG_-sIXI0038_-0301-00003-000001-01_RAS_denoised.nii']

# %%
int(file_list[0][8:11])

def indexing(x):
    return int(x[8:11])

# %%
f_list=[]
for f in file_list:
    x = indexing(f)
    f_list.append(x)
    
f_list
# Out:
# [16,
#  138,
#  77,
#  468,
#  629,
#  496,
#  639,
#  336,
#  420,
#  307,
#  219,
#  303,
#  178,
#  423,
#  309,
#  279,
#  344,
#  153,
#  123,
#  536,
#  331,
#  143,
#  474,
#  450,
#  528,
#  268,
#  170,
#  233,
#  87,
#  587,
#  640,
#  368,
#  222,
#  431,
#  193,
#  44,
#  76,
#  158,
#  119,
#  27,
#  495,
#  114,
#  662,
#  109,
#  200,
#  188,
#  300,
#  393,
#  442,
#  576,
#  351,
#  461,
#  573,
#  597,
#  164,
#  574,
#  207,
#  26,
#  192,
#  28,
#  413,
#  594,
#  63,
#  621,
#  294,
#  399,
#  498,
#  641,
#  84,
#  232,
#  196,
#  417,
#  332,
#  24,
#  493,
#  411,
#  50,
#  552,
#  37,
#  209,
#  55,
#  390,
#  315,
#  401,
#  548,
#  17,
#  113,
#  154,
#  595,
#  45,
#  652,
#  342,
#  653,
#  36,
#  265,
#  500,
#  64,
#  182,
#  115,
#  415,
#  549,
#  388,
#  463,
#  23,
#  112,
#  488,
#  308,
#  359,
#  433,
#  20,
#  408,
#  365,
#  418,
#  381,
#  364,
#  469,
#  430,
#  370,
#  288,
#  241,
#  454,
#  35,
#  330,
#  371,
#  43,
#  480,
#  416,
#  644,
#  157,
#  625,
#  118,
#  73,
#  464,
#  426,
#  183,
#  648,
#  456,
#  409,
#  230,
#  348,
#  592,
#  166,
#  324,
#  61,
#  558,
#  172,
#  41,
#  491,
#  523,
#  551,
#  312,
#  305,
#  503,
#  197,
#  434,
#  224,
#  517,
#  74,
#  375,
#  400,
#  563,
#  120,
#  406,
#  326,
#  285,
#  186,
#  100,
#  286,
#  25,
#  199,
#  266,
#  617,
#  22,
#  223,
#  231,
#  210,
#  372,
#  145,
#  29,
#  510,
#  251,
#  460,
#  65,
#  502,
#  21,
#  427,
#  181,
#  140,
#  382,
#  237,
#  494,
#  227,
#  487,
#  142,
#  244,
#  99,
#  306,
#  299,
#  550,
#  512,
#  588,
#  584,
#  311,
#  54,
#  317,
#  319,
#  320,
#  111,
#  42,
#  397,
#  297,
#  505,
#  229,
#  129,
#  108,
#  318,
#  504,
#  622,
#  293,
#  398,
#  389,
#  391,
#  507,
#  70,
#  361,
#  432,
#  78,
#  31,
#  543,
#  122,
#  208,
#  422,
#  46,
#  542,
#  89,
#  532,
#  40,
#  69,
#  410,
#  287,
#  184,
#  298,
#  189,
#  539,
#  402,
#  478,
#  555,
#  350,
#  627,
#  110,
#  360,
#  134,
#  121,
#  236,
#  569,
#  541,
#  68,
#  30,
#  582,
#  412,
#  404,
#  66,
#  141,
#  479,
#  86,
#  425,
#  367,
#  234,
#  19,
#  473,
#  619,
#  379,
#  414,
#  156,
#  151,
#  535,
#  58,
#  225,
#  630,
#  179,
#  103,
#  579,
#  62,
#  486,
#  467,
#  394,
#  501,
#  419,
#  407,
#  376,
#  291,
#  177,
#  475,
#  607,
#  249,
#  325,
#  194,
#  269,
#  553,
#  90,
#  489,
#  571,
#  314,
#  403,
#  424,
#  91,
#  578,
#  618,
#  616,
#  380,
#  596,
#  476,
#  53,
#  626,
#  562,
#  310,
#  60,
#  198,
#  405,
#  321,
#  449,
#  533,
#  169,
#  135,
#  477,
#  534,
#  191,
#  238,
#  358,
#  71,
#  304,
#  98,
#  250,
#  651,
#  554,
#  270,
#  369,
#  322,
#  289,
#  560,
#  547,
#  101,
#  455,
#  116,
#  377,
#  506,
#  392,
#  447,
#  642,
#  395,
#  246,
#  292,
#  499,
#  75,
#  139,
#  429,
#  591,
#  85,
#  144,
#  492,
#  290,
#  585,
#  185,
#  561,
#  462,
#  247,
#  459,
#  2,
#  378,
#  470,
#  490,
#  497,
#  264,
#  240,
#  106,
#  107,
#  373,
#  428,
#  531,
#  458,
#  38]

# %%
len(f_list)
# Out:
# 381

# %%
IXI_df1 = pd.DataFrame(zip(f_list, file_list), columns = ['IXI_ID', 'file_name'])

# %%
IXI_df2 = pd.merge(IXI_df1, age_df, how='outer', on='IXI_ID')

# %%
IXI_df3 = IXI_df2.drop_duplicates(['IXI_ID']
                                  )
IXI_df4 = IXI_df3.dropna()

# %%
IXI_df4 = IXI_df4.drop('IXI_ID',axis=1)
IXI_df4
# Out:
#                                              file_name        AGE
# 0    swc1nIXI016-Guys-0697-IXI3DMPRAG_-s231_-0301-0...  55.167693
# 1    swc1nIXI138-Guys-0746-IXI3DMPRAG_-s240_-0401-0...  33.138946
# 2    swc1nIXI077-Guys-0752-IXI3DMPRAG_-s242_-0301-0...  36.479124
# 3    swc1nIXI468-Guys-0985-MPRAGESEN_-s417_-0301-00...  67.698836
# 4    swc1nIXI629-Guys-1095-MPRAGESEN_-sIXI62_-0301-...  59.263518
# ..                                                 ...        ...
# 399  swc1nIXI373-IOP-0967-SAGFSPGR_-sIXI37_-0003-00...  58.792608
# 400  swc1nIXI428-Guys-0996-MPRAGESEN_-s419_-0301-00...  55.540041
# 401  swc1nIXI531-Guys-1057-MPRAGESEN_-s427_-0301-00...  75.937029
# 403  swc1nIXI458-Guys-0993-MPRAGESEN_-s418_-0301-00...  70.710472
# 404  swc1nIXI038-Guys-0729-IXI3DMPRAG_-sIXI0038_-03...  21.382615
#
# [381 rows x 2 columns]

# %%
from torch.utils.data import Dataset

torch.manual_seed(0)

class PBA_Dataset(Dataset):
    def __init__(self, data_dir, dataframe ,  transform=None):
        path2data = data_dir
        
        filenames = dataframe['file_name'].to_list()
        
        self.full_filenames = [os.path.join(path2data, f) for f in filenames]
        
        labels_df = dataframe
        labels_df.set_index('file_name', inplace=True)
        
        self.labels = [labels_df.loc[filename].values[0] for filename in filenames]
        
        self.transform = transform
        
    def __len__(self):
        return len(self.full_filenames)
    def __getitem__(self, idx):
        image_3d = nib.load(self.full_filenames[idx])
        image = image_3d.get_fdata()
        image = (image - image.min())/(image.max()-image.min())
        image = image*255.0
        image = np.expand_dims(image, axis=0)
        
        label = self.labels[idx]
        return image, label
    
import torchvision.transforms as transforms
data_transformer = transforms.Compose([transforms.ToTensor()])

data_dir = './IXI/'

# %%
from sklearn.model_selection import train_test_split

def get_data(data_file):
    data = data_file
    print("data.shape: {}".format(data.shape))

    trainingSet, test_df = train_test_split(data, test_size=0.2, random_state=45346)
    train_df, val_df = train_test_split(trainingSet, test_size=0.2, random_state=257572)

    print("Train.shape: {}, Val.shape: {}, Test.shape: {}".format(train_df.shape, val_df.shape, test_df.shape))

    data.loc[train_df.index, 'split_type'] = "Train"
    data.loc[val_df.index, 'split_type'] = "Val"
    data.loc[test_df.index, 'split_type'] = "Test"

    train_df = data.loc[train_df.index, :]
    val_df = data.loc[val_df.index, :]
    test_df = data.loc[test_df.index, :]

    return train_df, val_df, test_df

# %%
train_df, val_df, test_df = get_data(IXI_df4)
# Out:
# data.shape: (381, 2)
# Train.shape: (243, 2), Val.shape: (61, 2), Test.shape: (77, 2)

# %%
train_data = PBA_Dataset(data_dir, train_df, data_transformer)
val_data = PBA_Dataset(data_dir, val_df, data_transformer)
test_data = PBA_Dataset(data_dir, test_df, data_transformer)

# %%
from torch.utils.data import DataLoader

# %%
# Hyper parameters
NUM_EPOCHS = 100
BATCH_SIZE = 16
LEARNING_RATE = 0.001
IMAGE_SHAPE = (121, 145, 121)

# %%
trn_loader = DataLoader(train_data, shuffle=True, num_workers=4, batch_size=BATCH_SIZE, drop_last=True)
val_loader = DataLoader(val_data, shuffle=True, num_workers=4, batch_size=BATCH_SIZE, drop_last=True)
tst_loader = DataLoader(test_data, shuffle=True,batch_size=BATCH_SIZE)

# %%
print(trn_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f5d07d7edd0>

# %%
for (X_train, y_train) in trn_loader:

    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    print(y_train)
    break
# Out:
# X_train: torch.Size([1, 1, 121, 145, 121]) type: torch.DoubleTensor
# y_train: torch.Size([1]) type: torch.DoubleTensor
# tensor([42.2204], dtype=torch.float64)

# %%
'''class Model3D(nn.Module):
    def __init__(self, n_classes = 1):
        super(Model3D,self).__init__()
        self.conv1 = nn.Conv3d(1, 32, kernel_size=3,stride=(1,1,1),padding=1)
        self.conv2 = nn.Conv3d(32, 64, kernel_size=3,stride=(1,1,1),padding=1)
        self.conv3 = nn.Conv3d(64, 128, kernel_size=3,stride=(1,1,1),padding=1)
        self.conv4 = nn.Conv3d(128, 256, kernel_size=3,stride=(1,1,1),padding=1)
        self.conv5 = nn.Conv3d(256, 256, kernel_size=3,stride=(1,1,1),padding=1)
        self.conv6 = nn.Conv3d(256, 64, kernel_size=1,stride=(1,1,1))

        self.batchnorm1 = nn.BatchNorm3d(32)
        self.batchnorm2 = nn.BatchNorm3d(64)
        self.batchnorm3 = nn.BatchNorm3d(128)
        self.batchnorm4 = nn.BatchNorm3d(256)
        self.batchnorm5 = nn.BatchNorm3d(256)
        self.batchnorm6 = nn.BatchNorm3d(64)

        self.maxpool = nn.MaxPool3d(kernel_size=(2,2,2),stride=(2,2,2))
        self.avgpool = nn.AvgPool3d(kernel_size=(3,4,3),stride=(1,1,1))
        self.dropout = nn.Dropout3d(p=0.5)
        self.relu = nn.ReLU()
        self.classifier = nn.Conv3d(64, n_classes, kernel_size=1, stride=(1,1,1))
        self.softmax = nn.Softmax(dim=1)

    def forward(self,x):
        #input size = (B, 1, 160 , 192, 160)
        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = self.maxpool(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = self.batchnorm2(x)
        x = self.maxpool(x)
        x = self.relu(x)
        x = self.conv3(x)
        x = self.batchnorm3(x)
        x = self.maxpool(x)
        x = self.relu(x)
        x = self.conv4(x)
        x = self.batchnorm4(x)
        x = self.maxpool(x)
        x = self.relu(x)
        x = self.conv5(x)
        x = self.batchnorm5(x)
        x = self.maxpool(x)
        x = self.relu(x)
        # feature map with (B, 256, 5, 6, 5)
        x = self.conv6(x)
        x = self.batchnorm6(x)
        x = self.relu(x)
        x = self.avgpool(x)
        x = self.dropout(x)
        x = self.classifier(x)
        x = x.view(-1, self._to_linear)
        
        return x
        '''
# Out:
# 'class Model3D(nn.Module):\n    def __init__(self, n_classes = 1):\n        super(Model3D,self).__init__()\n        self.conv1 = nn.Conv3d(1, 32, kernel_size=3,stride=(1,1,1),padding=1)\n        self.conv2 = nn.Conv3d(32, 64, kernel_size=3,stride=(1,1,1),padding=1)\n        self.conv3 = nn.Conv3d(64, 128, kernel_size=3,stride=(1,1,1),padding=1)\n        self.conv4 = nn.Conv3d(128, 256, kernel_size=3,stride=(1,1,1),padding=1)\n        self.conv5 = nn.Conv3d(256, 256, kernel_size=3,stride=(1,1,1),padding=1)\n        self.conv6 = nn.Conv3d(256, 64, kernel_size=1,stride=(1,1,1))\n\n        self.batchnorm1 = nn.BatchNorm3d(32)\n        self.batchnorm2 = nn.BatchNorm3d(64)\n        self.batchnorm3 = nn.BatchNorm3d(128)\n        self.batchnorm4 = nn.BatchNorm3d(256)\n        self.batchnorm5 = nn.BatchNorm3d(256)\n        self.batchnorm6 = nn.BatchNorm3d(64)\n\n        self.maxpool = nn.MaxPool3d(kernel_size=(2,2,2),stride=(2,2,2))\n        self.avgpool = nn.AvgPool3d(kernel_size=(3,4,3),stride=(1,1,1))\n        self.dropout = nn.Dropout3d(p=0.5)\n        self.relu = nn.ReLU()\n        self.classifier = nn.Conv3d(64, n_classes, kernel_size=1, stride=(1,1,1))\n        self.softmax = nn.Softmax(dim=1)\n\n    def forward(self,x):\n        #input size = (B, 1, 160 , 192, 160)\n        x = self.conv1(x)\n        x = self.batchnorm1(x)\n        x = self.maxpool(x)\n        x = self.relu(x)\n        x = self.conv2(x)\n        x = self.batchnorm2(x)\n        x = self.maxpool(x)\n        x = self.relu(x)\n        x = self.conv3(x)\n        x = self.batchnorm3(x)\n        x = self.maxpool(x)\n        x = self.relu(x)\n        x = self.conv4(x)\n        x = self.batchnorm4(x)\n        x = self.maxpool(x)\n        x = self.relu(x)\n        x = self.conv5(x)\n        x = self.batchnorm5(x)\n        x = self.maxpool(x)\n        x = self.relu(x)\n        # feature map with (B, 256, 5, 6, 5)\n        x = self.conv6(x)\n        x = self.batchnorm6(x)\n        x = self.relu(x)\n        x = self.avgpool(x)\n        x = self.dropout(x)\n        x = self.classifier(x)\n        x = x.view(-1, self._to_linear)\n        \n        return x\n        '

# %%
class Model3D(nn.Module):
    def __init__(self):
        super(Model3D, self).__init__()
        self.block1 = nn.Sequential(
            nn.Conv3d(1, 8, 3, stride=1),
            nn.ReLU(),
            nn.Conv3d(8, 8, 3, stride=1),
            nn.BatchNorm3d(8),
            nn.ReLU(),
            nn.MaxPool3d(2, stride=2))

        self.block2 = nn.Sequential(
            nn.Conv3d(8, 16, 3, stride=1),
            nn.ReLU(),
            nn.Conv3d(16, 16, 3, stride=1),
            nn.BatchNorm3d(16),
            nn.ReLU(),
            nn.MaxPool3d(2, stride=2))

        self.block3 = nn.Sequential(
            nn.Conv3d(16, 32, 3, stride=1),
            nn.ReLU(),
            nn.Conv3d(32, 32, 3, stride=1),
            nn.BatchNorm3d(32),
            nn.ReLU(),
            nn.MaxPool3d(2, stride=2))

        self.block4 = nn.Sequential(
            nn.Conv3d(32, 64, 3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv3d(64, 64, 3, stride=1, padding=1),
            nn.BatchNorm3d(64),
            nn.ReLU(),
            nn.MaxPool3d(2, stride=2))

        self.block5 = nn.Sequential(
            nn.Conv3d(64, 128, 3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv3d(128, 128, 3, stride=1, padding=1),
            nn.BatchNorm3d(128),
            nn.ReLU(),
            nn.MaxPool3d(2, stride=2)
        )

        self.classifier = nn.Linear(1536, 1)


    def forward(self, x):
        x = self.block1(x)
        # print(x.shape)
        x = self.block2(x)
        # print(x.shape)
        x = self.block3(x)
        # print(x.shape)
        x = self.block4(x)
        # print(x.shape)
        x = self.block5(x)
        # print(x.shape)
        x = self.classifier(x.view(-1, x.shape[1]*x.shape[2]*x.shape[3]*x.shape[4]))
        # print(x.shape)
        

        return x

# %%
model = Model3D().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.MSELoss()

# %%
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter()

# %%
def train(model, train_loader, optimizer):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        
        data, target = data.float().to(DEVICE), target.float().to(DEVICE)
        optimizer.zero_grad()
        output = model(data)
  
        loss = criterion(output.squeeze(), target)
        
        loss.backward()
        optimizer.step()

# %%
def eval(model, test_loader):
    model.eval()
    test_loss=0
    
    
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.float().to(DEVICE), target.float().to(DEVICE)
            output = model(data)
           
            
            test_loss += criterion(output.squeeze(), target).item()
        test_loss /= len(test_loader.dataset)
    return test_loss

# %%
import time
import copy

def train_baseline(model, train_loader, val_loader,
                   optimizer, num_epochs = NUM_EPOCHS):
     
   
    
      for epoch in range(1, num_epochs + 1):
            since = time.time()
            train(model, train_loader, optimizer)
            train_loss = eval(model, train_loader)
            writer.add_scalar("loss/train_eval", train_loss, epoch)
            val_loss = eval(model, val_loader)
            writer.add_scalar("loss/val_eval", val_loss, epoch)

            if epoch % 10 == 0:
              for name, param in model.named_parameters():
                writer.add_histogram(name, param.clone().cpu().data.numpy(), epoch)
            time_elapsed = time.time() - since
            print('----------epoch {}----------'.format(epoch))
        
            print('train Loss: {:.4f}'
              .format(train_loss))
            print('val Loss: {:.4f}'
              .format(val_loss))
            print('Completed in {:.0f}m {:.0f}s'
              .format(time_elapsed // 60, time_elapsed % 60))
           
      return model

# %%
base = train_baseline(model, trn_loader, val_loader, optimizer, NUM_EPOCHS)
writer.flush()
writer.close()
# Out:
# /home/guest/Desktop/IXI/venv/lib/python3.10/site-packages/torch/nn/modules/loss.py:530: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ----------epoch 1----------
# train Loss: 41.0703
# val Loss: 40.1788
# Completed in 0m 19s
# ----------epoch 2----------
# train Loss: 184.1154
# val Loss: 186.5449
# Completed in 0m 17s
# ----------epoch 3----------
# train Loss: 17.1760
# val Loss: 18.4904
# Completed in 0m 16s
# ----------epoch 4----------
# train Loss: 45.7149
# val Loss: 48.7135
# Completed in 0m 17s
# ----------epoch 5----------
# train Loss: 16.4194
# val Loss: 17.8272
# Completed in 0m 16s
# ----------epoch 6----------
# train Loss: 20.9814
# val Loss: 21.0391
# Completed in 0m 16s
# ----------epoch 7----------
# train Loss: 33.3017
# val Loss: 36.9703
# Completed in 0m 16s
# ----------epoch 8----------
# train Loss: 19.0692
# val Loss: 21.9971
# Completed in 0m 16s
# ----------epoch 9----------
# train Loss: 19.7203
# val Loss: 19.1730
# Completed in 0m 16s
# ----------epoch 10----------
# train Loss: 14.6595
# val Loss: 15.5902
# Completed in 0m 16s
# ----------epoch 11----------
# train Loss: 19.7393
# val Loss: 19.8627
# Completed in 0m 16s
# ----------epoch 12----------
# train Loss: 13.8737
# val Loss: 17.4169
# Completed in 0m 16s
# ----------epoch 13----------
# train Loss: 14.6736
# val Loss: 16.9728
# Completed in 0m 16s
# ----------epoch 14----------
# train Loss: 13.6877
# val Loss: 17.4399
# Completed in 0m 16s
# ----------epoch 15----------
# train Loss: 19.1266
# val Loss: 22.9027
# Completed in 0m 16s
# ----------epoch 16----------
# train Loss: 18.2143
# val Loss: 22.6904
# Completed in 0m 16s
# ----------epoch 17----------
# train Loss: 15.9715
# val Loss: 20.8727
# Completed in 0m 17s
# ----------epoch 18----------
# train Loss: 15.0746
# val Loss: 16.9581
# Completed in 0m 16s
# ----------epoch 19----------
# train Loss: 24.6008
# val Loss: 23.8661
# Completed in 0m 16s
# ----------epoch 20----------
# train Loss: 11.6747
# val Loss: 15.6012
# Completed in 0m 16s
# ----------epoch 21----------
# train Loss: 14.6602
# val Loss: 19.4590
# Completed in 0m 16s
# ----------epoch 22----------
# train Loss: 14.3670
# val Loss: 16.7493
# Completed in 0m 16s
# ----------epoch 23----------
# train Loss: 14.3252
# val Loss: 19.3806
# Completed in 0m 16s
# ----------epoch 24----------
# train Loss: 12.0838
# val Loss: 15.6438
# Completed in 0m 16s
# ----------epoch 25----------
# train Loss: 20.7732
# val Loss: 21.6113
# Completed in 0m 16s
# ----------epoch 26----------
# train Loss: 12.6402
# val Loss: 17.6205
# Completed in 0m 16s
# ----------epoch 27----------
# train Loss: 13.8000
# val Loss: 18.1561
# Completed in 0m 16s
# ----------epoch 28----------
# train Loss: 19.7249
# val Loss: 24.1496
# Completed in 0m 16s
# ----------epoch 29----------
# train Loss: 11.5072
# val Loss: 15.8567
# Completed in 0m 16s
# ----------epoch 30----------
# train Loss: 12.2588
# val Loss: 16.2795
# Completed in 0m 16s
# ----------epoch 31----------
# train Loss: 25.3083
# val Loss: 29.1921
# Completed in 0m 16s
# ----------epoch 32----------
# train Loss: 15.7643
# val Loss: 18.2868
# Completed in 0m 16s
# ----------epoch 33----------
# train Loss: 13.4299
# val Loss: 16.7067
# Completed in 0m 16s
# ----------epoch 34----------
# train Loss: 14.1088
# val Loss: 17.1621
# Completed in 0m 16s
# ----------epoch 35----------
# train Loss: 22.0592
# val Loss: 26.2144
# Completed in 0m 16s
# ----------epoch 36----------
# train Loss: 16.8751
# val Loss: 19.3021
# Completed in 0m 17s
# ----------epoch 37----------
# train Loss: 27.7167
# val Loss: 31.6853
# Completed in 0m 17s
# ----------epoch 38----------
# train Loss: 33.1726
# val Loss: 36.2582
# Completed in 0m 16s
# ----------epoch 39----------
# train Loss: 23.6158
# val Loss: 27.2918
# Completed in 0m 16s
# ----------epoch 40----------
# train Loss: 13.6952
# val Loss: 18.3163
# Completed in 0m 17s
# ----------epoch 41----------
# train Loss: 13.0786
# val Loss: 15.8511
# Completed in 0m 16s
# ----------epoch 42----------
# train Loss: 14.1802
# val Loss: 17.9105
# Completed in 0m 16s
# ----------epoch 43----------
# train Loss: 11.5601
# val Loss: 15.3148
# Completed in 0m 16s
# ----------epoch 44----------
# train Loss: 13.5606
# val Loss: 18.6145
# Completed in 0m 16s
# ----------epoch 45----------
# train Loss: 13.3814
# val Loss: 16.7473
# Completed in 0m 16s
# ----------epoch 46----------
# train Loss: 11.9821
# val Loss: 15.6710
# Completed in 0m 16s
# ----------epoch 47----------
# train Loss: 17.0025
# val Loss: 18.8701
# Completed in 0m 16s
# ----------epoch 48----------
# train Loss: 12.8558
# val Loss: 18.1937
# Completed in 0m 16s
# ----------epoch 49----------
# train Loss: 11.7417
# val Loss: 17.0764
# Completed in 0m 16s
# ----------epoch 50----------
# train Loss: 10.8055
# val Loss: 16.1276
# Completed in 0m 17s
# ----------epoch 51----------
# train Loss: 11.0904
# val Loss: 15.5465
# Completed in 0m 16s
# ----------epoch 52----------
# train Loss: 23.2219
# val Loss: 28.1354
# Completed in 0m 16s
# ----------epoch 53----------
# train Loss: 16.7812
# val Loss: 18.8773
# Completed in 0m 16s
# ----------epoch 54----------
# train Loss: 14.7496
# val Loss: 17.2919
# Completed in 0m 16s
# ----------epoch 55----------
# train Loss: 11.5225
# val Loss: 15.6529
# Completed in 0m 16s
# ----------epoch 56----------
# train Loss: 14.7564
# val Loss: 19.8171
# Completed in 0m 16s
# ----------epoch 57----------
# train Loss: 10.7363
# val Loss: 16.2100
# Completed in 0m 16s
# ----------epoch 58----------
# train Loss: 13.7596
# val Loss: 18.6517
# Completed in 0m 16s
# ----------epoch 59----------
# train Loss: 11.7278
# val Loss: 16.5236
# Completed in 0m 16s
# ----------epoch 60----------
# train Loss: 15.6685
# val Loss: 20.5048
# Completed in 0m 16s
# ----------epoch 61----------
# train Loss: 11.4933
# val Loss: 16.6831
# Completed in 0m 16s
# ----------epoch 62----------
# train Loss: 13.7367
# val Loss: 16.9880
# Completed in 0m 16s
# ----------epoch 63----------
# train Loss: 18.4190
# val Loss: 20.2384
# Completed in 0m 16s
# ----------epoch 64----------
# train Loss: 11.3614
# val Loss: 15.8024
# Completed in 0m 16s
# ----------epoch 65----------
# train Loss: 17.7859
# val Loss: 23.3187
# Completed in 0m 16s
# ----------epoch 66----------
# train Loss: 14.3827
# val Loss: 16.6638
# Completed in 0m 16s
# ----------epoch 67----------
# train Loss: 14.5058
# val Loss: 19.7361
# Completed in 0m 16s
# ----------epoch 68----------
# train Loss: 14.6895
# val Loss: 17.2170
# Completed in 0m 16s
# ----------epoch 69----------
# train Loss: 10.2097
# val Loss: 15.3663
# Completed in 0m 16s
# ----------epoch 70----------
# train Loss: 27.8264
# val Loss: 32.0265
# Completed in 0m 16s
# ----------epoch 71----------
# train Loss: 14.1174
# val Loss: 17.0015
# Completed in 0m 16s
# ----------epoch 72----------
# train Loss: 15.0757
# val Loss: 20.2290
# Completed in 0m 16s
# ----------epoch 73----------
# train Loss: 11.2538
# val Loss: 16.0432
# Completed in 0m 16s
# ----------epoch 74----------
# train Loss: 14.4036
# val Loss: 17.1867
# Completed in 0m 16s
# ----------epoch 75----------
# train Loss: 17.1211
# val Loss: 19.0180
# Completed in 0m 16s
# ----------epoch 76----------
# train Loss: 10.6760
# val Loss: 15.2234
# Completed in 0m 16s
# ----------epoch 77----------
# train Loss: 11.1896
# val Loss: 15.1855
# Completed in 0m 16s
# ----------epoch 78----------
# train Loss: 11.5602
# val Loss: 15.7718
# Completed in 0m 16s
# ----------epoch 79----------
# train Loss: 11.0350
# val Loss: 16.0420
# Completed in 0m 16s
# ----------epoch 80----------
# train Loss: 12.5422
# val Loss: 16.2647
# Completed in 0m 16s
# ----------epoch 81----------
# train Loss: 11.7795
# val Loss: 15.9423
# Completed in 0m 16s
# ----------epoch 82----------
# train Loss: 21.1656
# val Loss: 22.5569
# Completed in 0m 16s
# ----------epoch 83----------
# train Loss: 12.2138
# val Loss: 17.5241
# Completed in 0m 16s
# ----------epoch 84----------
# train Loss: 11.6418
# val Loss: 16.3759
# Completed in 0m 16s
# ----------epoch 85----------
# train Loss: 12.9948
# val Loss: 16.1652
# Completed in 0m 16s
# ----------epoch 86----------
# train Loss: 13.5007
# val Loss: 16.4021
# Completed in 0m 16s
# ----------epoch 87----------
# train Loss: 15.6622
# val Loss: 18.1289
# Completed in 0m 16s
# ----------epoch 88----------
# train Loss: 10.9128
# val Loss: 16.3250
# Completed in 0m 16s
# ----------epoch 89----------
# train Loss: 17.4450
# val Loss: 19.4611
# Completed in 0m 16s
# ----------epoch 90----------
# train Loss: 12.1770
# val Loss: 17.0980
# Completed in 0m 16s
# ----------epoch 91----------
# train Loss: 12.1789
# val Loss: 17.0123
# Completed in 0m 16s
# ----------epoch 92----------
# train Loss: 13.6128
# val Loss: 16.8375
# Completed in 0m 16s
# ----------epoch 93----------
# train Loss: 11.4317
# val Loss: 16.2964
# Completed in 0m 16s
# ----------epoch 94----------
# train Loss: 11.6161
# val Loss: 15.8083
# Completed in 0m 16s
# ----------epoch 95----------
# train Loss: 20.2313
# val Loss: 25.1075
# Completed in 0m 16s
# ----------epoch 96----------
# train Loss: 12.2562
# val Loss: 17.0153
# Completed in 0m 16s
# ----------epoch 97----------
# train Loss: 14.4509
# val Loss: 19.4159
# Completed in 0m 16s
# ----------epoch 98----------
# train Loss: 11.5206
# val Loss: 16.0786
# Completed in 0m 16s
# ----------epoch 99----------
# train Loss: 11.4857
# val Loss: 16.4847
# Completed in 0m 16s
# ----------epoch 100----------
# train Loss: 11.7348
# val Loss: 16.0568
# Completed in 0m 16s

# %%
#torch.save(model.state_dict(), './Adam_RMSE3.pth')

# %%
writer.close()
